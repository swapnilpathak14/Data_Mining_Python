# %%
##To upload a folder on Jupyter Notebook

## Step 1: Convert the folder into zip file
## Step 2: Upload the zip file in the notebook
## Step 3: Unzip the file by running the code below

import zipfile as zf
files = zf.ZipFile("Data-Mining-With-Python-master.zip", 'r')
files.extractall('DATA MINING WITH PYTHON')
files.close()

# %% [markdown]
# <b>SECTION 1.1 - DATA CLEANING

# %%
import pandas as pd
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt  

# %matplotlib  inline

# %%
df = pd.read_csv('single_family_home_values.csv') # zillow
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-80b87ba6f8b6> in <module>
# ----> 1 df = pd.read_csv('single_family_home_values.csv') # zillow
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
df=pd.read_csv('S:\NRTI SM\PIRPLE\Data-Mining-With-Python-master\Data-Mining-With-Python-master\Part 2\single_family_home_values.csv')
# Out:
#   File "<ipython-input-3-c578d226a896>", line 1
#     df=pd.read_csv('S:\NRTI SM\PIRPLE\Data-Mining-With-Python-master\Data-Mining-With-Python-master\Part 2\single_family_home_values.csv')
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: malformed \N character escape

# %%
df=pd.read_csv("S:\\NRTI SM\\PIRPLE\\Data-Mining-With-Python-master\\Data-Mining-With-Python-master\\Part 2\\single_family_home_values.csv")

# %%
df.head() #Returns first 5 rows by default
# Out:
#           id              address    city state  zipcode   latitude  \
# 0   39525749      8171 E 84th Ave  Denver    CO    80022  39.849160
# 1  184578398    10556 Wheeling St  Denver    CO    80022  39.888020
# 2  184430015  3190 Wadsworth Blvd  Denver    CO    80033  39.761710
# 3  155129946  3040 Wadsworth Blvd  Denver    CO    80033  39.760780
# 4     245107      5615 S Eaton St  Denver    CO    80123  39.616181
#
#     longitude  bedrooms  bathrooms  rooms  squareFootage  lotSize  yearBuilt  \
# 0 -104.893468         3        2.0      6           1378     9968     2003.0
# 1 -104.830930         2        2.0      6           1653     6970     2004.0
# 2 -105.081070         3        1.0      0           1882    23875     1917.0
# 3 -105.081060         4        3.0      0           2400    11500     1956.0
# 4 -105.058812         3        4.0      8           2305     5600     1998.0
#
#   lastSaleDate  lastSaleAmount priorSaleDate  priorSaleAmount  estimated_value
# ...

# %%
df.shape
# Out:
# (15000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15000 non-null  int64
#  1   address          15000 non-null  object
#  2   city             15000 non-null  object
#  3   state            15000 non-null  object
#  4   zipcode          15000 non-null  int64
#  5   latitude         14985 non-null  float64
#  6   longitude        14985 non-null  float64
#  7   bedrooms         15000 non-null  int64
#  8   bathrooms        15000 non-null  float64
#  9   rooms            15000 non-null  int64
#  10  squareFootage    15000 non-null  int64
#  11  lotSize          15000 non-null  int64
#  12  yearBuilt        14999 non-null  float64
#  13  lastSaleDate     15000 non-null  object
#  14  lastSaleAmount   15000 non-null  int64
#  15  priorSaleDate    11173 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id       zipcode      latitude     longitude      bedrooms  \
# count  1.500000e+04  15000.000000  14985.000000  14985.000000  15000.000000
# mean   5.176229e+07  80204.919467     39.740538   -104.964076      2.708400
# std    6.190876e+07      9.715263      0.023555      0.039788      0.897231
# min    1.433670e+05  80022.000000     39.614531   -105.108440      0.000000
# 25%    1.004802e+07  80205.000000     39.727634   -104.978737      2.000000
# 50%    2.563241e+07  80206.000000     39.748048   -104.957689      3.000000
# 75%    5.114222e+07  80207.000000     39.758214   -104.937522      3.000000
# max    3.209481e+08  80209.000000     39.888020   -104.830930     15.000000
#
#           bathrooms         rooms  squareFootage       lotSize     yearBuilt  \
# count  15000.000000  15000.000000   15000.000000   15000.00000  14999.000000
# mean       2.195067      6.164133    1514.504400    5820.76620   1929.517168
# ...

# %%
df.fillna('Null') #To fill NA/NaN in place of holes such as (eg.:0)
# Out:
#               id                    address    city state  zipcode   latitude  \
# 0       39525749            8171 E 84th Ave  Denver    CO    80022   39.84916
# 1      184578398          10556 Wheeling St  Denver    CO    80022   39.88802
# 2      184430015        3190 Wadsworth Blvd  Denver    CO    80033   39.76171
# 3      155129946        3040 Wadsworth Blvd  Denver    CO    80033   39.76078
# 4         245107            5615 S Eaton St  Denver    CO    80123  39.616181
# ...          ...                        ...     ...   ...      ...        ...
# 14995   51411356              802 S High St  Denver    CO    80209  39.701902
# 14996   21721153           214 S Lincoln St  Denver    CO    80209  39.712608
# 14997   12995320              870 S Race St  Denver    CO    80209  39.700736
# 14998   39611615         130 S Lafayette St  Denver    CO    80209  39.714088
# 14999   42961679  100 S University Blvd # 1  Denver    CO    80209  39.714399
#
# ...

# %%
df2=df.fillna(df.mean())

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15000 non-null  int64
#  1   address          15000 non-null  object
#  2   city             15000 non-null  object
#  3   state            15000 non-null  object
#  4   zipcode          15000 non-null  int64
#  5   latitude         15000 non-null  float64
#  6   longitude        15000 non-null  float64
#  7   bedrooms         15000 non-null  int64
#  8   bathrooms        15000 non-null  float64
#  9   rooms            15000 non-null  int64
#  10  squareFootage    15000 non-null  int64
#  11  lotSize          15000 non-null  int64
#  12  yearBuilt        15000 non-null  float64
#  13  lastSaleDate     15000 non-null  object
#  14  lastSaleAmount   15000 non-null  int64
#  15  priorSaleDate    11173 non-null  object
# ...

# %%
sns.boxplot(df.estimated_value)
# Out:
# C:\Users\lucif\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='estimated_value'>

# %%
df[['estimated_value','yearBuilt','priorSaleAmount']]
# Out:
#        estimated_value  yearBuilt  priorSaleAmount
# 0               239753     2003.0         165700.0
# 1               343963     2004.0              NaN
# 2               488840     1917.0              NaN
# 3               494073     1956.0              0.0
# 4               513676     1998.0              0.0
# ...                ...        ...              ...
# 14995          1080081     1922.0              NaN
# 14996           807306     1890.0         557500.0
# 14997          1737156     2007.0        1208214.0
# 14998          2008794     2005.0         405000.0
# 14999          1421401     2001.0         925000.0
#
# [15000 rows x 3 columns]

# %%
df[['estimated_value','yearBuilt','priorSaleAmount']].head(3)
# Out:
#    estimated_value  yearBuilt  priorSaleAmount
# 0           239753     2003.0         165700.0
# 1           343963     2004.0              NaN
# 2           488840     1917.0              NaN

# %% [markdown]
# #### Filter out Noise, Slice Df

# %%
df[df.estimated_value<=800000]
# Out:
#               id              address    city state  zipcode   latitude  \
# 0       39525749      8171 E 84th Ave  Denver    CO    80022  39.849160
# 1      184578398    10556 Wheeling St  Denver    CO    80022  39.888020
# 2      184430015  3190 Wadsworth Blvd  Denver    CO    80033  39.761710
# 3      155129946  3040 Wadsworth Blvd  Denver    CO    80033  39.760780
# 4         245107      5615 S Eaton St  Denver    CO    80123  39.616181
# ...          ...                  ...     ...   ...      ...        ...
# 14989   23766957  421 S Washington St  Denver    CO    80209  39.708869
# 14990    4511745     255 S Downing St  Denver    CO    80209  39.711870
# 14992  184311569       445 S Pearl St  Denver    CO    80209  39.708452
# 14993   42985979    1016 S Emerson St  Denver    CO    80209  39.698090
# 14994  150304831        376 S High St  Denver    CO    80209  39.709681
#
#         longitude  bedrooms  bathrooms  rooms  squareFootage  lotSize  \
# ...

# %%
df[df.estimated_value<=800000].shape
# Out:
# (12690, 18)

# %%
df=df[df.estimated_value<=1000000]

# %%
sns.boxplot(df.estimated_value)
# Out:
# C:\Users\lucif\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='estimated_value'>

# %%
df.estimated_value.hist()
# Out:
# <AxesSubplot:>

# %%
#fliter, noise, slice df
df[(df.estimated_value<=1000000) & (df.yearBuilt>2013) & (df.zipcode==80209)]
# Out:
#               id              address    city state  zipcode   latitude  \
# 13229    3455195        866 S York St  Denver    CO    80209  39.700791
# 13276   39512040        764 S York St  Denver    CO    80209  39.702607
# 13316   11586398        450 S Vine St  Denver    CO    80209  39.708351
# 13428   11586742    636 S Williams St  Denver    CO    80209  39.704969
# 13431  184305844        456 S High St  Denver    CO    80209  39.708197
# 13766    7652681    408 S Franklin St  Denver    CO    80209  39.709074
# 13812   39708952  611 S Washington St  Denver    CO    80209  39.705403
# 13948  184305843        450 S High St  Denver    CO    80209  39.708333
# 14162   30566405    876 S Williams St  Denver    CO    80209  39.700646
# 14982   43208991   731 S Elizabeth St  Denver    CO    80209  39.703135
#
#         longitude  bedrooms  bathrooms  rooms  squareFootage  lotSize  \
# 13229 -104.960246         3        2.0      8           3332     6250
# ...

# %%
df.zipcode.unique()
# Out:
# array([80022, 80033, 80123, 80203, 80204, 80205, 80206, 80207, 80209],
#       dtype=int64)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df[['lastSaleAmount','estimated_value']])

# %%
sns.pairplot(df[['lastSaleAmount','estimated_value','yearBuilt']])

# %%
sns.pairplot(df[['lastSaleAmount','estimated_value','zipcode']],hue='zipcode')

# %%
sns.stripplot(x=df.zipcode,y=df.estimated_value)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='estimated_value'>

# %%
df=df[df.lastSaleAmount<=1000000]

# %%
sns.pairplot(df[['lastSaleAmount', 'estimated_value' , 'zipcode']], hue='zipcode')

# %%
#datetime conversion
df['lastSaleDate']=pd.to_datetime(df.lastSaleDate)

# %%
sns.violinplot(x=df.zipcode, y=df.estimated_value)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='estimated_value'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13528 entries, 0 to 14996
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               13528 non-null  int64
#  1   address          13528 non-null  object
#  2   city             13528 non-null  object
#  3   state            13528 non-null  object
#  4   zipcode          13528 non-null  int64
#  5   latitude         13516 non-null  float64
#  6   longitude        13516 non-null  float64
#  7   bedrooms         13528 non-null  int64
#  8   bathrooms        13528 non-null  float64
#  9   rooms            13528 non-null  int64
#  10  squareFootage    13528 non-null  int64
#  11  lotSize          13528 non-null  int64
#  12  yearBuilt        13527 non-null  float64
#  13  lastSaleDate     13528 non-null  datetime64[ns]
#  14  lastSaleAmount   13528 non-null  int64
#  15  priorSaleDate    10145 non-null  object
# ...

# %%
#date is not in the date time format, it is in the object format

pd.to_datetime(df.priorSaleDate)
# Out:
# 0       2004-05-13
# 1              NaT
# 2              NaT
# 3       2008-06-27
# 4       2011-12-29
#            ...
# 14991          NaT
# 14992          NaT
# 14993   2013-06-07
# 14994   1994-05-06
# 14996   2012-07-23
# Name: priorSaleDate, Length: 13528, dtype: datetime64[ns]

# %%
#Assign
df['priorSaleDate']=pd.to_datetime(df.priorSaleDate)

# %%
df['lastSaleDate']=pd.to_datetime(df.lastSaleDate)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13528 entries, 0 to 14996
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               13528 non-null  int64
#  1   address          13528 non-null  object
#  2   city             13528 non-null  object
#  3   state            13528 non-null  object
#  4   zipcode          13528 non-null  int64
#  5   latitude         13516 non-null  float64
#  6   longitude        13516 non-null  float64
#  7   bedrooms         13528 non-null  int64
#  8   bathrooms        13528 non-null  float64
#  9   rooms            13528 non-null  int64
#  10  squareFootage    13528 non-null  int64
#  11  lotSize          13528 non-null  int64
#  12  yearBuilt        13527 non-null  float64
#  13  lastSaleDate     13528 non-null  datetime64[ns]
#  14  lastSaleAmount   13528 non-null  int64
#  15  priorSaleDate    10145 non-null  datetime64[ns]
# ...

# %%
df.lastSaleDate.dt.year
# Out:
# 0        2009
# 1        2004
# 2        2008
# 3        2008
# 4        2012
#          ...
# 14991    2010
# 14992    1998
# 14993    2017
# 14994    2015
# 14996    2015
# Name: lastSaleDate, Length: 13528, dtype: int64

# %%
df.lastSaleDate.dt.weekday
# Out:
# 0        3
# 1        3
# 2        3
# 3        1
# 4        2
#         ..
# 14991    0
# 14992    2
# 14993    2
# 14994    3
# 14996    3
# Name: lastSaleDate, Length: 13528, dtype: int64

# %%
df['weekday_lastSaleDate']=df.lastSaleDate.dt.weekday
df['year_lastSaleDate']=df.lastSaleDate.dt.year

# %%
df['weekday_priorSaleDate']=df.priorSaleDate.dt.weekday
df['year_priorSaleDate']=df.priorSaleDate.dt.year

# %%
df['year_between_last_sales']=df.year_lastSaleDate-df.year_priorSaleDate

# %%
df.corr()
# Out:
#                                id   zipcode  latitude  longitude  bedrooms  \
# id                       1.000000 -0.017807 -0.069186   0.036254  0.051837
# zipcode                 -0.017807  1.000000  0.520665   0.392314 -0.044632
# latitude                -0.069186  0.520665  1.000000   0.546734 -0.018914
# longitude                0.036254  0.392314  0.546734   1.000000  0.004068
# bedrooms                 0.051837 -0.044632 -0.018914   0.004068  1.000000
# bathrooms                0.104204 -0.072286 -0.105081   0.093368  0.416227
# rooms                    0.074876 -0.002389 -0.120804  -0.003916  0.686362
# squareFootage            0.128993 -0.078276 -0.132342   0.035984  0.647186
# lotSize                 -0.005053 -0.088581  0.006034   0.071611  0.002030
# yearBuilt                0.013253 -0.226105 -0.012229   0.044619 -0.115946
# lastSaleAmount           0.161514  0.062188 -0.179761   0.186699  0.219678
# ...

# %%
df.corr().loc['estimated_value', : ]
# Out:
# id                         0.167920
# zipcode                    0.118983
# latitude                  -0.195019
# longitude                  0.243197
# bedrooms                   0.365225
# bathrooms                  0.644067
# rooms                      0.577256
# squareFootage              0.693455
# lotSize                   -0.046089
# yearBuilt                 -0.246495
# lastSaleAmount             0.733167
# priorSaleAmount            0.566069
# estimated_value            1.000000
# weekday_lastSaleDate      -0.005012
# year_lastSaleDate          0.042601
# weekday_priorSaleDate     -0.015108
# year_priorSaleDate        -0.058705
# year_between_last_sales    0.085144
# Name: estimated_value, dtype: float64

# %%
df.corr().loc['estimated_value', : ].sort_values(ascending=False)
# Out:
# estimated_value            1.000000
# lastSaleAmount             0.733167
# squareFootage              0.693455
# bathrooms                  0.644067
# rooms                      0.577256
# priorSaleAmount            0.566069
# bedrooms                   0.365225
# longitude                  0.243197
# id                         0.167920
# zipcode                    0.118983
# year_between_last_sales    0.085144
# year_lastSaleDate          0.042601
# weekday_lastSaleDate      -0.005012
# weekday_priorSaleDate     -0.015108
# lotSize                   -0.046089
# year_priorSaleDate        -0.058705
# latitude                  -0.195019
# yearBuilt                 -0.246495
# Name: estimated_value, dtype: float64

# %% [markdown]
# ## Practical Applications of DATA MINING

# %%
#GROUP BY
df.groupby('zipcode').estimated_value.mean()
# Out:
# zipcode
# 80022    291858.000000
# 80033    491456.500000
# 80123    429436.138889
# 80203    585525.417391
# 80204    379985.975542
# 80205    491863.209086
# 80206    683682.715389
# 80207    502487.946100
# 80209    674495.222756
# Name: estimated_value, dtype: float64

# %%
#GROUP BY
df.groupby(['zipcode','yearBuilt']).estimated_value.min()
# Out:
# zipcode  yearBuilt
# 80022    2003.0       239753
#          2004.0       343963
# 80033    1917.0       488840
#          1956.0       494073
# 80123    1959.0       311996
#                        ...
# 80209    2010.0       686395
#          2012.0       970614
#          2014.0       994114
#          2015.0       709102
#          2016.0       682810
# Name: estimated_value, Length: 589, dtype: int64

# %%
df.groupby('zipcode').estimated_value.median().reset_index()
# Out:
#    zipcode  estimated_value
# 0    80022         291858.0
# 1    80033         491456.5
# 2    80123         378609.5
# 3    80203         558178.0
# 4    80204         349374.0
# 5    80205         464498.0
# 6    80206         683442.0
# 7    80207         447097.0
# 8    80209         675667.0

# %%
#PD.MERGE 
#Merge Df

# %%
df2=df.groupby('zipcode').estimated_value.median().reset_index()

# %%
df2
# Out:
#    zipcode  estimated_value
# 0    80022         291858.0
# 1    80033         491456.5
# 2    80123         378609.5
# 3    80203         558178.0
# 4    80204         349374.0
# 5    80205         464498.0
# 6    80206         683442.0
# 7    80207         447097.0
# 8    80209         675667.0

# %%
df2.columns=['zipcode','median_value'] ##Column Renamed

# %%
df2
# Out:
#    zipcode  median_value
# 0    80022      291858.0
# 1    80033      491456.5
# 2    80123      378609.5
# 3    80203      558178.0
# 4    80204      349374.0
# 5    80205      464498.0
# 6    80206      683442.0
# 7    80207      447097.0
# 8    80209      675667.0

# %%
df3=pd.merge(df,df2,on='zipcode',how='left')

# %%
df3.head(3)
# Out:
#           id              address    city state  zipcode  latitude  \
# 0   39525749      8171 E 84th Ave  Denver    CO    80022  39.84916
# 1  184578398    10556 Wheeling St  Denver    CO    80022  39.88802
# 2  184430015  3190 Wadsworth Blvd  Denver    CO    80033  39.76171
#
#     longitude  bedrooms  bathrooms  rooms  ...  lastSaleAmount  priorSaleDate  \
# 0 -104.893468         3        2.0      6  ...           75000     2004-05-13
# 1 -104.830930         2        2.0      6  ...          216935            NaT
# 2 -105.081070         3        1.0      0  ...          330000            NaT
#
#    priorSaleAmount estimated_value  weekday_lastSaleDate year_lastSaleDate  \
# 0         165700.0          239753                     3              2009
# 1              NaN          343963                     3              2004
# 2              NaN          488840                     3              2008
#
#    weekday_priorSaleDate  year_priorSaleDate  year_between_last_sales  \
# ...
