# %%
import pandas as pd
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt  

# %matplotlib  inline

# %%
df=pd.read_csv("S:\\NRTI SM\\PIRPLE\\Data-Mining-With-Python-master\\data.csv")

# %%
df.shape
# Out:
# (32941, 12)

# %%
df.head(15)
# Out:
#          location       iso_code        date   total_vaccinations  \
# 0   #country+name  #country+code       #date  #total+vaccinations
# 1     Afghanistan            AFG  2021-02-22                    0
# 2     Afghanistan            AFG  2021-02-23                  NaN
# 3     Afghanistan            AFG  2021-02-24                  NaN
# 4     Afghanistan            AFG  2021-02-25                  NaN
# 5     Afghanistan            AFG  2021-02-26                  NaN
# 6     Afghanistan            AFG  2021-02-27                  NaN
# 7     Afghanistan            AFG  2021-02-28                 8200
# 8     Afghanistan            AFG  2021-03-01                  NaN
# 9     Afghanistan            AFG  2021-03-02                  NaN
# 10    Afghanistan            AFG  2021-03-03                  NaN
# 11    Afghanistan            AFG  2021-03-04                  NaN
# 12    Afghanistan            AFG  2021-03-05                  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32941 entries, 0 to 32940
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             32941 non-null  object
#  1   iso_code                             32941 non-null  object
#  2   date                                 32941 non-null  object
#  3   total_vaccinations                   19348 non-null  object
#  4   people_vaccinated                    18497 non-null  float64
#  5   people_fully_vaccinated              15498 non-null  float64
#  6   daily_vaccinations_raw               16340 non-null  float64
#  7   daily_vaccinations                   32690 non-null  object
#  8   total_vaccinations_per_hundred       19347 non-null  float64
#  9   people_vaccinated_per_hundred        18497 non-null  float64
#  10  people_fully_vaccinated_per_hundred  15498 non-null  float64
# ...

# %%
df['date']=pd.to_datetime(df.date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-222462c47b09> in <module>
# ----> 1 df['date']=pd.to_datetime(df.date)
#
# ...

# %%
df.drop([0], axis=0).head(5)
# Out:
#       location iso_code        date total_vaccinations  people_vaccinated  \
# 1  Afghanistan      AFG  2021-02-22                  0                0.0
# 2  Afghanistan      AFG  2021-02-23                NaN                NaN
# 3  Afghanistan      AFG  2021-02-24                NaN                NaN
# 4  Afghanistan      AFG  2021-02-25                NaN                NaN
# 5  Afghanistan      AFG  2021-02-26                NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw daily_vaccinations  \
# 1                      NaN                     NaN                NaN
# 2                      NaN                     NaN               1367
# 3                      NaN                     NaN               1367
# 4                      NaN                     NaN               1367
# 5                      NaN                     NaN               1367
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df['date']=pd.to_datetime(df.date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-222462c47b09> in <module>
# ----> 1 df['date']=pd.to_datetime(df.date)
#
# ...

# %%
df1=df.drop([0], axis=0).head(5)

# %%
df1.head()
# Out:
#       location iso_code        date total_vaccinations  people_vaccinated  \
# 1  Afghanistan      AFG  2021-02-22                  0                0.0
# 2  Afghanistan      AFG  2021-02-23                NaN                NaN
# 3  Afghanistan      AFG  2021-02-24                NaN                NaN
# 4  Afghanistan      AFG  2021-02-25                NaN                NaN
# 5  Afghanistan      AFG  2021-02-26                NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw daily_vaccinations  \
# 1                      NaN                     NaN                NaN
# 2                      NaN                     NaN               1367
# 3                      NaN                     NaN               1367
# 4                      NaN                     NaN               1367
# 5                      NaN                     NaN               1367
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df1['date']=pd.to_datetime(df1.date)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 1 to 5
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             5 non-null      object
#  1   iso_code                             5 non-null      object
#  2   date                                 5 non-null      datetime64[ns]
#  3   total_vaccinations                   1 non-null      object
#  4   people_vaccinated                    1 non-null      float64
#  5   people_fully_vaccinated              0 non-null      float64
#  6   daily_vaccinations_raw               0 non-null      float64
#  7   daily_vaccinations                   4 non-null      object
#  8   total_vaccinations_per_hundred       1 non-null      float64
#  9   people_vaccinated_per_hundred        1 non-null      float64
#  10  people_fully_vaccinated_per_hundred  0 non-null      float64
# ...

# %%
df1['Weekday']=df1.date.dt.weekday
#Looking for weekdays in the date.
#Monday to Sunday numbered as 0 to 6

# %%
df1.head(5)
# Out:
#       location iso_code       date total_vaccinations  people_vaccinated  \
# 1  Afghanistan      AFG 2021-02-22                  0                0.0
# 2  Afghanistan      AFG 2021-02-23                NaN                NaN
# 3  Afghanistan      AFG 2021-02-24                NaN                NaN
# 4  Afghanistan      AFG 2021-02-25                NaN                NaN
# 5  Afghanistan      AFG 2021-02-26                NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw daily_vaccinations  \
# 1                      NaN                     NaN                NaN
# 2                      NaN                     NaN               1367
# 3                      NaN                     NaN               1367
# 4                      NaN                     NaN               1367
# 5                      NaN                     NaN               1367
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...
